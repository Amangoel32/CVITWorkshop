# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
from scipy.linalg import svd
import matplotlib.pyplot as plt
import numpy as np
import time
import sys
from PIL import Image

I=cv2.imread("./flag.png",0)
cv2_imshow(I)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7FC5DF265630>

# %%
print(I.shape)
print("Integeres required to store is ",I.shape[0]*I.shape[1])
# Out:
# (183, 275)
# Integeres required to store is  50325

# %%
U, d, V = svd(I)
# print(U)
print(d.shape)
dd=np.diag(d)
print(dd.shape)
print(dd)
# print(VT)
# Out:
# (183,)
# (183, 183)
# [[4.0194543e+04 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 3.2539177e+03 0.0000000e+00 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 1.9986276e+03 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  ...
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 2.3905796e-03
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   2.3905796e-03 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   0.0000000e+00 7.6514715e-04]]

# %%
print(dd.shape)
print(np.diag(d[:i]).shape)
print(sys.getsizeof(I))

i=10
a=np.sum(d[:i])/np.sum(d)
print(a)
# Out:
# (183, 183)
# (99, 99)
# 50437
# 0.92424685

# %%
for i in range(2, 100):
    sum=0
    sum+=(U[:,:i].shape[0]*U[:,:i].shape[1])
    sum+=(dd[:i][:i].shape[0]*dd[:i][:i].shape[1])
    sum+=(V[:i,:].shape[0]*V[:i,:].shape[1])
    print("Compression Ratio",(sum/(I.shape[0]*I.shape[1]))*100)
    a=np.sum(d[:i])/np.sum(d)
    print("Information preserved",a*100,"%")
    A=np.matrix(U[:,:i])*np.diag(d[:i])
    B=np.matrix(A)*np.matrix(V[:i,:])
    # print(A.shape)
    # print(B.shape)
    plt.imshow(B, cmap='gray')
    title = "n = %s" % i
    plt.title(title)
    plt.show()
# Out:
# Compression Ratio 2.547441629408843
# Information preserved 73.78196716308594 %
# Compression Ratio 3.8211624441132637
# Information preserved 77.17593312263489 %
# Compression Ratio 5.094883258817686
# Information preserved 80.40645718574524 %
# Compression Ratio 6.368604073522106
# Information preserved 83.04058313369751 %
# Compression Ratio 7.642324888226527
# Information preserved 85.61750054359436 %
# Compression Ratio 8.916045702930948
# Information preserved 87.45901584625244 %
# Compression Ratio 10.189766517635372
# Information preserved 89.26258087158203 %
# Compression Ratio 11.463487332339792
# Information preserved 90.99920988082886 %
# Compression Ratio 12.737208147044212
# Information preserved 92.42468476295471 %
# Compression Ratio 14.010928961748634
# Information preserved 93.62711906433105 %
# Compression Ratio 15.284649776453055
# Information preserved 94.74099278450012 %
# Compression Ratio 16.558370591157477
# Information preserved 95.5737829208374 %
# ...
